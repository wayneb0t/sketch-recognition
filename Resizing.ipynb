# %%
from PIL import Image
import datautils
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 5.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

# %%
res = 128
datautils.resize_images(res=res)
im_data = datautils.load_image("data/png{}/laptop/9555.png".format(res))
plt.imshow(im_data.reshape(res, res))
plt.show()
# Out:
# Resizing airplane
# Resizing alarm clock
# Resizing angel
# Resizing ant
# Resizing apple
# Resizing arm
# Resizing armchair
# Resizing ashtray
# Resizing axe
# Resizing backpack
# Resizing banana
# Resizing barn
# Resizing baseball bat
# Resizing basket
# Resizing bathtub
# Resizing bear (animal)
# Resizing bed
# Resizing bee
# Resizing beer-mug
# Resizing bell
# Resizing bench
# Resizing bicycle
# Resizing binoculars
# Resizing blimp
# Resizing book
# Resizing bookshelf
# Resizing boomerang
# Resizing bottle opener
# Resizing bowl
# Resizing brain
# Resizing bread
# Resizing bridge
# Resizing bulldozer
# Resizing bus
# Resizing bush
# Resizing butterfly
# Resizing cabinet
# Resizing cactus
# Resizing cake
# Resizing calculator
# Resizing camel
# Resizing camera
# Resizing candle
# Resizing cannon
# Resizing canoe
# Resizing car (sedan)
# Resizing carrot
# Resizing castle
# Resizing cat
# Resizing cell phone
# Resizing chair
# Resizing chandelier
# Resizing church
# Resizing cigarette
# Resizing cloud
# Resizing comb
# Resizing computer monitor
# Resizing computer-mouse
# Resizing couch
# Resizing cow
# Resizing crab
# Resizing crane (machine)
# Resizing crocodile
# Resizing crown
# Resizing cup
# Resizing diamond
# Resizing dog
# Resizing dolphin
# Resizing donut
# Resizing door
# Resizing door handle
# Resizing dragon
# Resizing duck
# Resizing ear
# Resizing elephant
# Resizing envelope
# Resizing eye
# Resizing eyeglasses
# Resizing face
# Resizing fan
# Resizing feather
# Resizing fire hydrant
# Resizing fish
# Resizing flashlight
# Resizing floor lamp
# Resizing flower with stem
# Resizing flying bird
# Resizing flying saucer
# Resizing foot
# Resizing fork
# Resizing frog
# Resizing frying-pan
# Resizing giraffe
# Resizing grapes
# Resizing grenade
# Resizing guitar
# Resizing hamburger
# Resizing hammer
# Resizing hand
# Resizing harp
# Resizing hat
# Resizing head
# Resizing head-phones
# Resizing hedgehog
# Resizing helicopter
# Resizing helmet
# Resizing horse
# Resizing hot air balloon
# Resizing hot-dog
# Resizing hourglass
# Resizing house
# Resizing human-skeleton
# Resizing ice-cream-cone
# Resizing ipod
# Resizing kangaroo
# Resizing key
# Resizing keyboard
# Resizing knife
# Resizing ladder
# Resizing laptop
# Resizing leaf
# Resizing lightbulb
# Resizing lighter
# Resizing lion
# Resizing lobster
# Resizing loudspeaker
# Resizing mailbox
# Resizing megaphone
# Resizing mermaid
# Resizing microphone
# Resizing microscope
# Resizing monkey
# Resizing moon
# Resizing mosquito
# Resizing motorbike
# Resizing mouse (animal)
# Resizing mouth
# Resizing mug
# Resizing mushroom
# Resizing nose
# Resizing octopus
# Resizing owl
# Resizing palm tree
# Resizing panda
# Resizing paper clip
# Resizing parachute
# Resizing parking meter
# Resizing parrot
# Resizing pear
# Resizing pen
# Resizing penguin
# Resizing person sitting
# Resizing person walking
# Resizing piano
# Resizing pickup truck
# Resizing pig
# Resizing pigeon
# Resizing pineapple
# Resizing pipe (for smoking)
# Resizing pizza
# Resizing potted plant
# Resizing power outlet
# Resizing present
# Resizing pretzel
# Resizing pumpkin
# Resizing purse
# Resizing rabbit
# Resizing race car
# Resizing radio
# Resizing rainbow
# Resizing revolver
# Resizing rifle
# Resizing rollerblades
# Resizing rooster
# Resizing sailboat
# Resizing santa claus
# Resizing satellite
# Resizing satellite dish
# Resizing saxophone
# Resizing scissors
# Resizing scorpion
# Resizing screwdriver
# Resizing sea turtle
# Resizing seagull
# Resizing shark
# Resizing sheep
# Resizing ship
# Resizing shoe
# Resizing shovel
# Resizing skateboard
# Resizing skull
# Resizing skyscraper
# Resizing snail
# Resizing snake
# Resizing snowboard
# Resizing snowman
# Resizing socks
# Resizing space shuttle
# Resizing speed-boat
# Resizing spider
# Resizing sponge bob
# Resizing spoon
# Resizing squirrel
# Resizing standing bird
# Resizing stapler
# Resizing strawberry
# Resizing streetlight
# Resizing submarine
# Resizing suitcase
# Resizing sun
# Resizing suv
# Resizing swan
# Resizing sword
# Resizing syringe
# Resizing t-shirt
# Resizing table
# Resizing tablelamp
# Resizing teacup
# Resizing teapot
# Resizing teddy-bear
# Resizing telephone
# Resizing tennis-racket
# Resizing tent
# Resizing tiger
# Resizing tire
# Resizing toilet
# Resizing tomato
# Resizing tooth
# Resizing toothbrush
# Resizing tractor
# Resizing traffic light
# Resizing train
# Resizing tree
# Resizing trombone
# Resizing trousers
# Resizing truck
# Resizing trumpet
# Resizing tv
# Resizing umbrella
# Resizing van
# Resizing vase
# Resizing violin
# Resizing walkie talkie
# Resizing wheel
# Resizing wheelbarrow
# Resizing windmill
# Resizing wine-bottle
# Resizing wineglass
# Resizing wrist-watch
# Resizing zebra
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d5e4fc868fd3> in <module>()
#       1 res = 128
#       2 datautils.resize_images(res=res)
# ----> 3 im_data = datautils.load_image("data/png{}/laptop/9555.png".format(res))
#       4 plt.imshow(im_data.reshape(res, res))
#       5 plt.show()
#
# /Users/xpandachuy/Projects/Courses/CS231n/sketch-recognition/datautils.py in load_image(path)
#      67
#      68 def load_image(path):
# ---> 69     im_data = imread(path, mode='L')
#      70     return im_data
#      71
#
# /usr/local/lib/python3.6/site-packages/scipy/misc/pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# /usr/local/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2408
#    2409     if filename:
# -> 2410         fp = builtins.open(filename, "rb")
#    2411         exclusive_fp = True
#    2412
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/png128/laptop/9555.png'
